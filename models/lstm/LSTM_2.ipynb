# %% [markdown]
# # LSTM Model Version 2 Testing

# %% [markdown]
# ## Goal & Setup
#
# - **Task:** given the past week of weather, predict the next 24 hours
# - **Target:** start with a **single variable** (e.g. `temperature`) — predicting multiple targets is a later extension (noted in Phase 3)
# - **Data:** 4-year subset of hourly weather (~35,000 rows) to keep experiments fast
# - **Approach:** direct multi-step forecast — the model outputs all 24 future values at once via a `Dense(24)` head

# %%
# Data Import
import sys
sys.path.append('../Data_Processing')
from full_cleaning_preprocessing_script import run_full_preprocessing

# General
import pandas as pd
import numpy as np
import os
from typing import List
import matplotlib.pyplot as plt

# Metrics Evaluation
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Deep Learning Architecture
from keras import models, Input, layers, optimizers, regularizers
from keras.layers import Normalization
from keras.optimizers.schedules import ExponentialDecay
from keras.callbacks import EarlyStopping
# Out:
# 2026-05-29 10:34:35.317256: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-29 10:34:35.477716: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-29 10:34:35.478569: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-29 10:34:35.702091: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-29 10:34:37.547330: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Phase 0 — Inputs (what the model expects)

# %%
df = run_full_preprocessing(
    data_folder = "/home/jpelletier/Downloads/data",
    start_date = "2019-01-01",
    end_date = "2024-12-31",
)
# Out:
# ============================================================
# DUCKSTRADAMUS — FULL PREPROCESSING PIPELINE
#   data_folder : /home/jpelletier/Downloads/data
#   date range  : 2019-01-01  →  2024-12-31
#   save_path   : /home/jpelletier/Downloads/data/preprocessed_data.csv
# ============================================================
#
# [1/9] Wholesale price...
#       Anchor df shape: (52585, 10)
#
# [2/9] Generation output...
#       Shape after merge: (52585, 19)
#
# [3/9] Wind...
#       Shape after merge: (52585, 29)
#
# [4/9] Solar...
#       Shape after merge: (52585, 41)
#
# [5/9] Temperature...
#       Shape after merge: (52585, 47)
#
# [6/9] Lake storage...
#       Merged: NI_TPO_Storage_LakeTaupo.csv  (prefix: 'NI_TPO_')
#       Merged: NI_WKA_Storage_LakeWaikaremoana.csv  (prefix: 'NI_WKA_')
#       Merged: SI_HWE_Storage_LakeHawea.csv  (prefix: 'SI_HWE_')
#       Merged: SI_MAN_Storage_LakeManapouri.csv  (prefix: 'SI_MAN_')
#       Merged: SI_OHA_Storage_LakeOhau.csv  (prefix: 'SI_OHA_')
#       Merged: SI_PKI_Storage_LakePukaki.csv  (prefix: 'SI_PKI_')
#       Merged: SI_TAU_Storage_LakeTeAnau.csv  (prefix: 'SI_TAU_')
#       Merged: SI_TKA_Storage_LakeTekapo.csv  (prefix: 'SI_TKA_')
#       Merged: SI_WAN_Storage_LakeWanaka.csv  (prefix: 'SI_WAN_')
#       Merged: SI_WPU_Storage_LakeWakatipu.csv  (prefix: 'SI_WPU_')
#       Shape after all lake merges: (52585, 67)
#
# [7/9] Holidays...
#       Shape after merge: (52585, 68)
#
# [8/9] Demand per zone...
#       Shape after merge: (52585, 73)
#
# [9/9] HVDC and scheduled outages...
#       Shape after merge: (52585, 81)
#    Saved to    : /home/jpelletier/Downloads/data/preprocessed_data.csv
#
# ============================================================
# ✅ Pipeline complete.
#    Final shape : (52585, 81)
#    Saved to    : /home/jpelletier/Downloads/data/preprocessed_data.csv
# ============================================================

# %%
df = df.set_index('datetime_utc12').sort_index()

# %%
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (52585, 80)
# ['el_price_dol_MWh_BEN2201', 'el_price_dol_MWh_HAY2201', 'el_price_dol_MWh_INV2201', 'el_price_dol_MWh_ISL2201', 'el_price_dol_MWh_KIK2201', 'el_price_dol_MWh_OTA2201', 'el_price_dol_MWh_RDF2201', 'el_price_dol_MWh_SFD2201', 'el_price_dol_MWh_WKM2201', 'Coal', 'Diesel', 'Ele', 'Gas', 'Geo', 'Hydro', 'Solar', 'Wind', 'Wood', 'palmerston_north_wind_kmh', 'palmerston_north_wind_dir_deg', 'wellington_wind_kmh', 'wellington_wind_dir_deg', 'harapaki_hawkesbay_wind_kmh', 'harapaki_hawkesbay_wind_dir_deg', 'te_uku_waikato_wind_kmh', 'te_uku_waikato_wind_dir_deg', 'kaiwera_downs_southland_wind_kmh', 'kaiwera_downs_southland_wind_dir_deg', 'auckland_shortwave_wm2', 'auckland_sunshine_s', 'christchurch_shortwave_wm2', 'christchurch_sunshine_s', 'wellington_shortwave_wm2', 'wellington_sunshine_s', 'hamilton_shortwave_wm2', 'hamilton_sunshine_s', 'tauranga_shortwave_wm2', 'tauranga_sunshine_s', 'dunedin_shortwave_wm2', 'dunedin_sunshine_s', 'auckland_temp_c', 'christchurch_temp_c', 'wellington_temp_c', 'hamilton_temp_c', 'tauranga_temp_c', 'dunedin_temp_c', 'NI_TPO__lake_level_m', 'NI_TPO__active_storage_mm³', 'NI_WKA__lake_level_m', 'NI_WKA__active_storage_mm³', 'SI_HWE__lake_level_m', 'SI_HWE__active_storage_mm³', 'SI_MAN__lake_level_m', 'SI_MAN__active_storage_mm³', 'SI_OHA__lake_level_m', 'SI_OHA__active_storage_mm³', 'SI_PKI__lake_level_m', 'SI_PKI__active_storage_mm³', 'SI_TAU__lake_level_m', 'SI_TAU__active_storage_mm³', 'SI_TKA__lake_level_m', 'SI_TKA__active_storage_mm³', 'SI_WAN__lake_level_m', 'SI_WAN__active_storage_mm³', 'SI_WPU__lake_level_m', 'SI_WPU__active_storage_mm³', 'holiday', 'demand_GWh_CNI', 'demand_GWh_LNI', 'demand_GWh_LSI', 'demand_GWh_UNI', 'demand_GWh_USI', 'avg_flow_MW', 'peak_flow_MW', 'Direction', 'outage_Gas_MW', 'outage_Hyd_MW', 'outage_Ter_MW', 'outage_Win_MW', 'outage_UNKN_MW']
#                      el_price_dol_MWh_BEN2201  el_price_dol_MWh_HAY2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   169.985                    171.76
# 2019-01-01 01:00:00                   156.335                    157.87
# 2019-01-01 02:00:00                   139.650                    141.00
# 2019-01-01 03:00:00                   128.845                    129.98
# 2019-01-01 04:00:00                   134.865                    136.14
#
#                      el_price_dol_MWh_INV2201  el_price_dol_MWh_ISL2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   180.715                   181.835
# 2019-01-01 01:00:00                   166.360                   167.215
# 2019-01-01 02:00:00                   148.550                   149.095
# 2019-01-01 03:00:00                   137.375                   137.215
# 2019-01-01 04:00:00                   144.585                   143.745
#
#                      el_price_dol_MWh_KIK2201  el_price_dol_MWh_OTA2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   184.255                   176.515
# 2019-01-01 01:00:00                   169.400                   162.070
# 2019-01-01 02:00:00                   151.050                   144.645
# 2019-01-01 03:00:00                   139.015                   133.355
# 2019-01-01 04:00:00                   145.670                   139.955
#
#                      el_price_dol_MWh_RDF2201  el_price_dol_MWh_SFD2201  \
# datetime_utc12
# 2019-01-01 00:00:00                   166.425                   169.515
# 2019-01-01 01:00:00                   152.940                   155.645
# 2019-01-01 02:00:00                   136.500                   138.990
# 2019-01-01 03:00:00                   125.830                   128.130
# 2019-01-01 04:00:00                   132.130                   134.465
#
#                      el_price_dol_MWh_WKM2201  Coal  ...  demand_GWh_UNI  \
# datetime_utc12                                       ...
# 2019-01-01 00:00:00                   167.185   0.0  ...           0.910
# 2019-01-01 01:00:00                   153.635   0.0  ...           0.889
# 2019-01-01 02:00:00                   137.120   0.0  ...           0.853
# 2019-01-01 03:00:00                   126.400   0.0  ...           0.833
# 2019-01-01 04:00:00                   132.725   0.0  ...           0.835
#
#                      demand_GWh_USI  avg_flow_MW  peak_flow_MW  Direction  \
# datetime_utc12
# 2019-01-01 00:00:00           0.528        137.5         148.0        1.0
# 2019-01-01 01:00:00           0.483        129.5         133.0        1.0
# 2019-01-01 02:00:00           0.457        126.0         128.0        1.0
# 2019-01-01 03:00:00           0.446        126.5         132.0        1.0
# 2019-01-01 04:00:00           0.460        146.0         155.0        1.0
#
#                      outage_Gas_MW  outage_Hyd_MW  outage_Ter_MW  \
# datetime_utc12
# 2019-01-01 00:00:00           40.0           84.0          590.0
# 2019-01-01 01:00:00           40.0           84.0          590.0
# 2019-01-01 02:00:00           40.0           84.0          590.0
# 2019-01-01 03:00:00           40.0           84.0          590.0
# 2019-01-01 04:00:00           40.0           84.0          590.0
#
#                      outage_Win_MW  outage_UNKN_MW
# datetime_utc12
# 2019-01-01 00:00:00           48.3            14.0
# 2019-01-01 01:00:00           48.3            14.0
# 2019-01-01 02:00:00           48.3            14.0
# 2019-01-01 03:00:00           48.3            14.0
# 2019-01-01 04:00:00           48.3            14.0
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Create Naive Baseline

# %%
df['naive_baseline'] = df['el_price_dol_MWh_OTA2201'].shift(1)

# %%
# Drop the first row since shift(1) gives NaN there
mask = df['naive_baseline'].notna()

mae  = mean_absolute_error(df.loc[mask, 'el_price_dol_MWh_OTA2201'], df.loc[mask, 'naive_baseline'])
rmse = np.sqrt(mean_squared_error(df.loc[mask, 'el_price_dol_MWh_OTA2201'], df.loc[mask, 'naive_baseline']))

print(f'MAE  : {mae:.4f}')
print(f'RMSE : {rmse:.4f}')
# Out:
# MAE  : 23.6814
# RMSE : 72.6089

# %% [markdown]
# ## Phase 1 — Lastmile Preprocessing

# %% [markdown]
# ### Observations
#
# Some columns with 18 and 6 missing values. Will simply impute and fill given extremely low percentage of these values (0.03% and 0.01%, respectivelly.
#
# Check with:
# - df.isnull().sum()
# - df.isnull().sum() / len(df) * 100

# %%
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_rows')

# %%
# 1. Ensure chronological order, no gaps
df = df.sort_index()

# %%
# 2. Handle missing values (weather sensors have gaps)
#    Forward-fill carries the last reading; back-fill covers any leading NaNs
df = df.ffill().bfill()

# %%
# 3. Add cyclical time features — helps the model learn daily & yearly rhythm
#    (Same sin/cos trick as the generation-data cyclic encoding)
hour = df.index.hour
doy  = df.index.dayofyear
df['hour_sin'] = np.sin(2 * np.pi * hour / 24)
df['hour_cos'] = np.cos(2 * np.pi * hour / 24)
df['doy_sin']  = np.sin(2 * np.pi * doy / 365)
df['doy_cos']  = np.cos(2 * np.pi * doy / 365)

# %%
# 4. (Optional) keep only the features you want the model to see
#    Fewer, relevant features = faster training and less overfitting on a small dataset

# %% [markdown]
# > **⚠️ Leakage note (different from David's Prophet case):**
# > David had to lag his price/production features by 24h because they would otherwise leak the future. For a *pure weather → weather* LSTM, the sliding-window construction in Phase 2 handles this structurally: `X` only ever contains the **past** window, and `y` only the **future** window. So no manual lagging is needed — **as long as every feature you include is something genuinely available at prediction time.** If you later add a feature that "knows the future," you'd need to lag it like David did.

# %% [markdown]
# ## Phase 2 — Data Preparation (Time Series sequences)

# %%
# ─── Configuration (all TUNE-able) ──────────────────────────────────
TARGET           = 'el_price_dol_MWh_OTA2201'   # TUNE: the weather variable to predict
INPUT_LENGTH     = 168             # TUNE: 7 days of hourly history as input. CHANGE LATER TO 336 TO LOOK AT 2 WEEKS
OUTPUT_LENGTH    = 24              # fixed: predict 24 hours ahead. CHANGE LATER TO 168 TO PREDICT 1 WEEK
HORIZON          = 1               # gap between last input and first prediction
STRIDE           = 1               # TUNE: step between consecutive sequences
FOLD_LENGTH      = 24 * 365        # TUNE: 1 year per fold
FOLD_STRIDE      = 24 * 182        # TUNE: ~6 month stride between folds
TRAIN_TEST_RATIO = 0.8

# Index of the target column WITHIN the feature array (needed for the baseline)
TARGET_COLUMN_IDX = df.columns.get_loc(TARGET)

# %%
# ─── Step 1: Create folds (sliding window over full dataset) ─────────
def get_folds(df: pd.DataFrame, fold_length: int, fold_stride: int) -> List[pd.DataFrame]:
    folds = []
    for idx in range(0, len(df), fold_stride):
        if (idx + fold_length) > len(df):
            break
        folds.append(df.iloc[idx:idx + fold_length, :])
    return folds

# %%
# ─── Step 2: Chronological train/test split per fold (with horizon gap) ──
def train_test_split(fold, train_test_ratio, input_length, horizon):
    train_end  = round(train_test_ratio * len(fold))
    test_start = train_end - input_length + horizon   # leaves lookback + gap
    return fold.iloc[:train_end], fold.iloc[test_start:]

# %%
# ─── Step 3: Extract (Xi, yi) sequence pairs ─────────────────────────
# NOTE: simplified from the bootcamp version to use positional indexing,
# so it works with a DatetimeIndex (the bootcamp version assumed a RangeIndex).
def get_X_y(fold, horizon, input_length, output_length, stride, shuffle=True):
    X, y = [], []
    n = len(fold)
    last_start = n - input_length - horizon - output_length + 2
    for start in range(0, last_start, stride):
        Xi = fold.iloc[start : start + input_length]
        y_start = start + input_length + horizon - 1
        yi = fold.iloc[y_start : y_start + output_length][TARGET]
        X.append(Xi.values)
        y.append(yi.values)
    X, y = np.array(X), np.array(y)
    if shuffle:
        idx = np.random.permutation(len(X))
        X, y = X[idx], y[idx]
    return X, y

# %%
# ─── Build folds and a first (Xi, yi) set to sanity-check shapes ─────
folds = get_folds(df, FOLD_LENGTH, FOLD_STRIDE)

fold_train, fold_test = train_test_split(folds[0], TRAIN_TEST_RATIO, INPUT_LENGTH, HORIZON)
X_train, y_train = get_X_y(fold_train, HORIZON, INPUT_LENGTH, OUTPUT_LENGTH, STRIDE)
X_test,  y_test  = get_X_y(fold_test,  HORIZON, INPUT_LENGTH, OUTPUT_LENGTH, STRIDE, shuffle=False)

print(f"Number of folds: {len(folds)}")
print(f"X_train: {X_train.shape}")   # (n_sequences, INPUT_LENGTH, N_FEATURES)
print(f"y_train: {y_train.shape}")   # (n_sequences, OUTPUT_LENGTH)
# Out:
# Number of folds: 11
# X_train: (6817, 168, 85)
# y_train: (6817, 24)

# %% [markdown]
# ## Phase 3 — Architecture

# %%
def init_model(X_train):
    # Normalization baked into the model, fitted on TRAIN data only (no leakage)
    normalizer = Normalization()
    normalizer.adapt(X_train)

    model = models.Sequential()
    model.add(Input(shape=X_train[0].shape))     # (INPUT_LENGTH, N_FEATURES)
    model.add(normalizer)

    # Recurrent layer
    model.add(layers.LSTM(units=64,               # MAKE EDITS HERE IF NEEDED: 32 OR 64
                          activation='tanh',      # alternative "SWISH or Swiss"
                          return_sequences=True,
                          dropout=0.2))           # TUNE: lighter than bootcamp 0.5

    # Recurrent layer
    model.add(layers.LSTM(units=32,               # MAKE EDITS HERE IF NEEDED: 32 OR 64
                          activation='tanh',      # alternative "SWISH or Swiss"
                          return_sequences=False,
                          dropout=0.2))           # TUNE: lighter than bootcamp 0.5

    # Dense hidden layer
    model.add(layers.Dense(32, activation='relu'))  # TUNE
    model.add(layers.Dropout(0.2))                  # TUNE

    # Output — one neuron per future timestep (24)
    model.add(layers.Dense(OUTPUT_LENGTH, activation='linear'))

    # Exponential decay learning rate
    lr_schedule = ExponentialDecay(initial_learning_rate=0.01,   # TUNE
                                   decay_steps=1000,
                                   decay_rate=0.5)
    model.compile(loss='huber',                                   # MAKE EDITS: change to MAE or Huber
                  optimizer=optimizers.Adam(learning_rate=lr_schedule),
                  metrics=['mae', 'root_mean_squared_error'])              # MAKE EDITS: change metrics reported if needed
    return model

# %%
model = init_model(X_train)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 168, 85)        │           171 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 168, 64)        │        38,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 24)             │           792 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,835 (206.39 KB)
#  Trainable params: 52,664 (205.72 KB)
#  Non-trainable params: 171 (688.00 B)

# %% [markdown]
# ## Phase 4 — Fit

# %%
def fit_model(model, X_train, y_train, verbose=1):
    es = EarlyStopping(monitor='val_loss',
                       patience=10,            # TUNE
                       mode='min',
                       restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        validation_split = 0.3,
        shuffle          = False,   # MANDATORY for time series
        batch_size       = 32,      # TUNE
        epochs           = 600,     # early stopping decides the real number
        callbacks        = [es],
        verbose          = verbose,
    )
    return model, history

# %%
model, history = fit_model(model, X_train, y_train)
# Out:
# Epoch 1/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 57.3664 - mae: 57.8639 - root_mean_squared_error: 82.6824 - val_loss: 40.3151 - val_mae: 40.8116 - val_root_mean_squared_error: 63.8833
# Epoch 2/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - loss: 41.4270 - mae: 41.9239 - root_mean_squared_error: 63.6036 - val_loss: 40.2084 - val_mae: 40.7052 - val_root_mean_squared_error: 63.5058
# Epoch 3/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - loss: 41.2280 - mae: 41.7249 - root_mean_squared_error: 63.2731 - val_loss: 40.2014 - val_mae: 40.6982 - val_root_mean_squared_error: 63.5331
# Epoch 4/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - loss: 41.1856 - mae: 41.6825 - root_mean_squared_error: 63.4256 - val_loss: 40.2267 - val_mae: 40.7233 - val_root_mean_squared_error: 63.6273
# Epoch 5/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 41.2531 - mae: 41.7499 - root_mean_squared_error: 63.5105 - val_loss: 40.2257 - val_mae: 40.7223 - val_root_mean_squared_error: 63.6545
# Epoch 6/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 104ms/step - loss: 41.2119 - mae: 41.7087 - root_mean_squared_error: 63.5174 - val_loss: 40.2311 - val_mae: 40.7277 - val_root_mean_squared_error: 63.6496
# Epoch 7/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - loss: 41.3389 - mae: 41.8358 - root_mean_squared_error: 63.4998 - val_loss: 40.2992 - val_mae: 40.7957 - val_root_mean_squared_error: 63.7949
# Epoch 8/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 39.8856 - mae: 40.3823 - root_mean_squared_error: 62.0198 - val_loss: 34.6537 - val_mae: 35.1496 - val_root_mean_squared_error: 57.6441
# Epoch 9/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 35.0955 - mae: 35.5917 - root_mean_squared_error: 56.0437 - val_loss: 31.7793 - val_mae: 32.2742 - val_root_mean_squared_error: 53.2299
# Epoch 10/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 34.0355 - mae: 34.5314 - root_mean_squared_error: 54.6157 - val_loss: 31.0599 - val_mae: 31.5550 - val_root_mean_squared_error: 52.4669
# Epoch 11/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 33.4560 - mae: 33.9518 - root_mean_squared_error: 53.7490 - val_loss: 30.9818 - val_mae: 31.4766 - val_root_mean_squared_error: 52.1435
# Epoch 12/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 33.2186 - mae: 33.7146 - root_mean_squared_error: 53.3911 - val_loss: 30.6411 - val_mae: 31.1361 - val_root_mean_squared_error: 51.4027
# Epoch 13/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - loss: 32.9263 - mae: 33.4221 - root_mean_squared_error: 52.8568 - val_loss: 30.2226 - val_mae: 30.7173 - val_root_mean_squared_error: 50.6290
# Epoch 14/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 32.8091 - mae: 33.3051 - root_mean_squared_error: 52.6090 - val_loss: 30.0553 - val_mae: 30.5501 - val_root_mean_squared_error: 50.6917
# Epoch 15/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 32.7701 - mae: 33.2658 - root_mean_squared_error: 52.5646 - val_loss: 29.9203 - val_mae: 30.4152 - val_root_mean_squared_error: 50.3830
# Epoch 16/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 32.5916 - mae: 33.0874 - root_mean_squared_error: 52.3435 - val_loss: 29.7788 - val_mae: 30.2736 - val_root_mean_squared_error: 50.6435
# Epoch 17/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 32.4735 - mae: 32.9695 - root_mean_squared_error: 52.2814 - val_loss: 29.6397 - val_mae: 30.1346 - val_root_mean_squared_error: 49.9498
# Epoch 18/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 32.3263 - mae: 32.8221 - root_mean_squared_error: 52.0281 - val_loss: 29.5218 - val_mae: 30.0163 - val_root_mean_squared_error: 49.9900
# Epoch 19/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 32.2199 - mae: 32.7157 - root_mean_squared_error: 51.7899 - val_loss: 29.4281 - val_mae: 29.9229 - val_root_mean_squared_error: 49.8447
# Epoch 20/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - loss: 32.1017 - mae: 32.5971 - root_mean_squared_error: 51.6862 - val_loss: 29.4323 - val_mae: 29.9268 - val_root_mean_squared_error: 49.7007
# Epoch 21/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - loss: 32.1182 - mae: 32.6140 - root_mean_squared_error: 51.6357 - val_loss: 29.2858 - val_mae: 29.7803 - val_root_mean_squared_error: 49.4164
# Epoch 22/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - loss: 31.9401 - mae: 32.4357 - root_mean_squared_error: 51.4646 - val_loss: 29.3724 - val_mae: 29.8670 - val_root_mean_squared_error: 49.7894
# Epoch 23/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 32.0195 - mae: 32.5153 - root_mean_squared_error: 51.6037 - val_loss: 29.2635 - val_mae: 29.7579 - val_root_mean_squared_error: 49.5664
# Epoch 24/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 32.0545 - mae: 32.5502 - root_mean_squared_error: 51.5405 - val_loss: 29.1431 - val_mae: 29.6373 - val_root_mean_squared_error: 49.3001
# Epoch 25/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 31.9370 - mae: 32.4325 - root_mean_squared_error: 51.4184 - val_loss: 29.1123 - val_mae: 29.6070 - val_root_mean_squared_error: 49.1479
# Epoch 26/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 31.8943 - mae: 32.3900 - root_mean_squared_error: 51.3568 - val_loss: 29.0625 - val_mae: 29.5569 - val_root_mean_squared_error: 49.1713
# Epoch 27/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 31.9346 - mae: 32.4303 - root_mean_squared_error: 51.4452 - val_loss: 29.0485 - val_mae: 29.5429 - val_root_mean_squared_error: 49.1316
# Epoch 28/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 98ms/step - loss: 31.8710 - mae: 32.3667 - root_mean_squared_error: 51.2099 - val_loss: 29.0412 - val_mae: 29.5360 - val_root_mean_squared_error: 49.1553
# Epoch 29/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - loss: 31.8847 - mae: 32.3804 - root_mean_squared_error: 51.1267 - val_loss: 29.0931 - val_mae: 29.5875 - val_root_mean_squared_error: 49.3786
# Epoch 30/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 116ms/step - loss: 31.8799 - mae: 32.3753 - root_mean_squared_error: 51.2796 - val_loss: 28.9955 - val_mae: 29.4899 - val_root_mean_squared_error: 49.0843
# Epoch 31/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 107ms/step - loss: 31.7223 - mae: 32.2179 - root_mean_squared_error: 51.1293 - val_loss: 28.9731 - val_mae: 29.4676 - val_root_mean_squared_error: 49.0399
# Epoch 32/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - loss: 31.7438 - mae: 32.2394 - root_mean_squared_error: 51.0756 - val_loss: 28.9989 - val_mae: 29.4931 - val_root_mean_squared_error: 49.2337
# Epoch 33/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - loss: 31.6883 - mae: 32.1839 - root_mean_squared_error: 51.1166 - val_loss: 28.9469 - val_mae: 29.4415 - val_root_mean_squared_error: 49.0360
# Epoch 34/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - loss: 31.7341 - mae: 32.2297 - root_mean_squared_error: 51.1800 - val_loss: 28.9338 - val_mae: 29.4284 - val_root_mean_squared_error: 48.9663
# Epoch 35/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 107ms/step - loss: 31.5993 - mae: 32.0948 - root_mean_squared_error: 50.9454 - val_loss: 28.9397 - val_mae: 29.4341 - val_root_mean_squared_error: 48.9705
# Epoch 36/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - loss: 31.6400 - mae: 32.1357 - root_mean_squared_error: 51.0568 - val_loss: 28.9270 - val_mae: 29.4215 - val_root_mean_squared_error: 48.9238
# Epoch 37/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - loss: 31.7229 - mae: 32.2184 - root_mean_squared_error: 51.0994 - val_loss: 28.9152 - val_mae: 29.4098 - val_root_mean_squared_error: 48.9694
# Epoch 38/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - loss: 31.7408 - mae: 32.2366 - root_mean_squared_error: 51.1527 - val_loss: 28.9127 - val_mae: 29.4071 - val_root_mean_squared_error: 49.0057
# Epoch 39/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - loss: 31.6510 - mae: 32.1467 - root_mean_squared_error: 51.0129 - val_loss: 28.8785 - val_mae: 29.3729 - val_root_mean_squared_error: 48.8175
# Epoch 40/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - loss: 31.5887 - mae: 32.0844 - root_mean_squared_error: 50.7660 - val_loss: 28.9036 - val_mae: 29.3981 - val_root_mean_squared_error: 48.9839
# Epoch 41/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - loss: 31.6220 - mae: 32.1176 - root_mean_squared_error: 50.9746 - val_loss: 28.8998 - val_mae: 29.3942 - val_root_mean_squared_error: 49.0182
# Epoch 42/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - loss: 31.8053 - mae: 32.3010 - root_mean_squared_error: 51.2497 - val_loss: 28.8611 - val_mae: 29.3556 - val_root_mean_squared_error: 48.8550
# Epoch 43/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 18s 123ms/step - loss: 31.6981 - mae: 32.1938 - root_mean_squared_error: 50.9745 - val_loss: 28.8755 - val_mae: 29.3700 - val_root_mean_squared_error: 48.9485
# Epoch 44/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - loss: 31.7586 - mae: 32.2541 - root_mean_squared_error: 51.1132 - val_loss: 28.8584 - val_mae: 29.3527 - val_root_mean_squared_error: 48.8540
# Epoch 45/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - loss: 31.7562 - mae: 32.2522 - root_mean_squared_error: 51.1416 - val_loss: 28.8725 - val_mae: 29.3668 - val_root_mean_squared_error: 48.8896
# Epoch 46/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - loss: 31.6545 - mae: 32.1503 - root_mean_squared_error: 50.9927 - val_loss: 28.8612 - val_mae: 29.3554 - val_root_mean_squared_error: 48.8771
# Epoch 47/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - loss: 31.5602 - mae: 32.0558 - root_mean_squared_error: 50.8669 - val_loss: 28.8786 - val_mae: 29.3729 - val_root_mean_squared_error: 48.9590
# Epoch 48/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - loss: 31.8174 - mae: 32.3130 - root_mean_squared_error: 51.1444 - val_loss: 28.8777 - val_mae: 29.3720 - val_root_mean_squared_error: 48.9555
# Epoch 49/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - loss: 31.6234 - mae: 32.1189 - root_mean_squared_error: 51.0559 - val_loss: 28.8628 - val_mae: 29.3571 - val_root_mean_squared_error: 48.8917
# Epoch 50/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - loss: 31.6524 - mae: 32.1481 - root_mean_squared_error: 51.0538 - val_loss: 28.8623 - val_mae: 29.3568 - val_root_mean_squared_error: 48.8890
# Epoch 51/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - loss: 31.6446 - mae: 32.1404 - root_mean_squared_error: 51.0243 - val_loss: 28.8520 - val_mae: 29.3464 - val_root_mean_squared_error: 48.8740
# Epoch 52/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - loss: 31.6405 - mae: 32.1359 - root_mean_squared_error: 51.1130 - val_loss: 28.8461 - val_mae: 29.3405 - val_root_mean_squared_error: 48.8363
# Epoch 53/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - loss: 31.5195 - mae: 32.0152 - root_mean_squared_error: 50.6844 - val_loss: 28.8357 - val_mae: 29.3302 - val_root_mean_squared_error: 48.8026
# Epoch 54/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - loss: 31.5484 - mae: 32.0439 - root_mean_squared_error: 50.9509 - val_loss: 28.8483 - val_mae: 29.3427 - val_root_mean_squared_error: 48.8555
# Epoch 55/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - loss: 31.6586 - mae: 32.1543 - root_mean_squared_error: 51.0181 - val_loss: 28.8474 - val_mae: 29.3418 - val_root_mean_squared_error: 48.8623
# Epoch 56/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - loss: 31.6977 - mae: 32.1935 - root_mean_squared_error: 51.2075 - val_loss: 28.8409 - val_mae: 29.3353 - val_root_mean_squared_error: 48.8282
# Epoch 57/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 104ms/step - loss: 31.5650 - mae: 32.0605 - root_mean_squared_error: 50.8564 - val_loss: 28.8426 - val_mae: 29.3370 - val_root_mean_squared_error: 48.8435
# Epoch 58/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - loss: 31.7230 - mae: 32.2185 - root_mean_squared_error: 51.0708 - val_loss: 28.8334 - val_mae: 29.3278 - val_root_mean_squared_error: 48.8111
# Epoch 59/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 103ms/step - loss: 31.6248 - mae: 32.1204 - root_mean_squared_error: 50.9389 - val_loss: 28.8407 - val_mae: 29.3351 - val_root_mean_squared_error: 48.8342
# Epoch 60/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - loss: 31.7139 - mae: 32.2095 - root_mean_squared_error: 51.0708 - val_loss: 28.8345 - val_mae: 29.3289 - val_root_mean_squared_error: 48.8111
# Epoch 61/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 105ms/step - loss: 31.8381 - mae: 32.3340 - root_mean_squared_error: 51.1869 - val_loss: 28.8302 - val_mae: 29.3247 - val_root_mean_squared_error: 48.7890
# Epoch 62/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - loss: 31.6023 - mae: 32.0979 - root_mean_squared_error: 50.8844 - val_loss: 28.8332 - val_mae: 29.3277 - val_root_mean_squared_error: 48.8042
# Epoch 63/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 104ms/step - loss: 31.6633 - mae: 32.1590 - root_mean_squared_error: 51.0241 - val_loss: 28.8309 - val_mae: 29.3253 - val_root_mean_squared_error: 48.8010
# Epoch 64/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - loss: 31.7239 - mae: 32.2196 - root_mean_squared_error: 51.1196 - val_loss: 28.8355 - val_mae: 29.3299 - val_root_mean_squared_error: 48.8245
# Epoch 65/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - loss: 31.5597 - mae: 32.0552 - root_mean_squared_error: 50.9334 - val_loss: 28.8351 - val_mae: 29.3295 - val_root_mean_squared_error: 48.8221
# Epoch 66/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - loss: 31.5942 - mae: 32.0896 - root_mean_squared_error: 50.9271 - val_loss: 28.8400 - val_mae: 29.3344 - val_root_mean_squared_error: 48.8457
# Epoch 67/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 104ms/step - loss: 31.6027 - mae: 32.0984 - root_mean_squared_error: 50.9325 - val_loss: 28.8410 - val_mae: 29.3354 - val_root_mean_squared_error: 48.8464
# Epoch 68/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - loss: 31.4214 - mae: 31.9171 - root_mean_squared_error: 50.7248 - val_loss: 28.8407 - val_mae: 29.3351 - val_root_mean_squared_error: 48.8480
# Epoch 69/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 31.5303 - mae: 32.0258 - root_mean_squared_error: 50.7614 - val_loss: 28.8397 - val_mae: 29.3341 - val_root_mean_squared_error: 48.8444
# Epoch 70/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 101ms/step - loss: 31.3895 - mae: 31.8849 - root_mean_squared_error: 50.6876 - val_loss: 28.8401 - val_mae: 29.3344 - val_root_mean_squared_error: 48.8457
# Epoch 71/600
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - loss: 31.6289 - mae: 32.1247 - root_mean_squared_error: 51.0154 - val_loss: 28.8386 - val_mae: 29.3330 - val_root_mean_squared_error: 48.8378

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'],     label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epoch'); plt.ylabel('MSE'); plt.legend()
plt.title('Learning curve'); plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Phase 5 — Evaluate & Cross-Validate

# %% [markdown]
# ### Single-fold evaluation + baseline

# %%
# LSTM performance on this fold's test set
res = model.evaluate(X_test, y_test, verbose=0)
mae_lstm = res[1]

# Baseline: repeat the last seen target value across all 24 future hours
def last_seen_value_baseline(X_test, y_test):
    last_seen = X_test[:, -1, TARGET_COLUMN_IDX].reshape(-1, 1)
    repeated  = np.repeat(last_seen, axis=1, repeats=OUTPUT_LENGTH)
    return np.mean(np.abs(y_test - repeated))

mae_baseline = last_seen_value_baseline(X_test, y_test)

print(f"Baseline MAE: {mae_baseline:.3f}")
print(f"LSTM MAE:     {mae_lstm:.3f}")
print(f"Improvement:  {(1 - mae_lstm/mae_baseline)*100:.1f}%")
# Out:
# Baseline MAE: 37.865
# LSTM MAE:     58.291
# Improvement:  -53.9%

# %% [markdown]
# ## Phase 6 — Predict the Next 24 Hours

# %%
# Build a single input window from the most recent data
latest_window = df.iloc[-INPUT_LENGTH:].values            # (INPUT_LENGTH, N_FEATURES)
latest_window = latest_window[np.newaxis, ...]            # (1, INPUT_LENGTH, N_FEATURES)

# Predict the next 24 hours
forecast_24h = model.predict(latest_window)[0]            # shape (24,)

# Attach future timestamps for readability
last_ts = df.index[-1]
future_index = pd.date_range(last_ts + pd.Timedelta(hours=1), periods=OUTPUT_LENGTH, freq='h')
forecast_series = pd.Series(forecast_24h, index=future_index, name=f'{TARGET}_forecast')

print(forecast_series)

# Quick visual
plt.figure(figsize=(12, 4))
df[TARGET].iloc[-INPUT_LENGTH:].plot(label='history')
forecast_series.plot(label='24h forecast', linestyle='--')
plt.legend(); plt.title(f'{TARGET}: last week + 24h forecast'); plt.grid(alpha=0.3)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 2024-12-31 01:00:00    99.376785
# 2024-12-31 02:00:00    99.517036
# 2024-12-31 03:00:00    99.648903
# 2024-12-31 04:00:00    99.528183
# 2024-12-31 05:00:00    99.453850
# 2024-12-31 06:00:00    99.299919
# 2024-12-31 07:00:00    99.277473
# 2024-12-31 08:00:00    99.068314
# 2024-12-31 09:00:00    98.835312
# 2024-12-31 10:00:00    98.725700
# 2024-12-31 11:00:00    98.910385
# 2024-12-31 12:00:00    98.987114
# 2024-12-31 13:00:00    98.964806
# 2024-12-31 14:00:00    98.702591
# 2024-12-31 15:00:00    98.664314
# 2024-12-31 16:00:00    98.683060
# 2024-12-31 17:00:00    98.715897
# 2024-12-31 18:00:00    98.676857
# 2024-12-31 19:00:00    98.841202
# 2024-12-31 20:00:00    98.601181
# 2024-12-31 21:00:00    98.589386
# 2024-12-31 22:00:00    98.578949
# 2024-12-31 23:00:00    98.549423
# 2025-01-01 00:00:00    98.505989
# Freq: h, Name: el_price_dol_MWh_OTA2201_forecast, dtype: float32
